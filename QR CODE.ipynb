# %% [markdown]
# # HOW TO GENERATE QR CODE

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image
img = mpimg.imread('PINKRAHS_qr_code.png')

# Display the image
plt.imshow(img)
plt.show()
